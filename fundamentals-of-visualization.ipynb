# %% [markdown]
# ## Fundamentals of visualization
# ### Graphic system for R language
# ### codes to Graphs minds to page and plots
# #### is mein ap ne code say graphs ko banana hai
# #### Here Im creat a three graphic chart

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set_theme(style="ticks",color_codes=True)
flights = sns.load_dataset("flights")
# sns.catplot(x= "sex", y= "survived", hue="class",kind= "bar", data=titanic)
sns.relplot(data=flights, x="year", y="passengers", hue="month", kind="line")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
titanic = sns.load_dataset("titanic")
titanic p1=sns.countplot(x='sex',data=titanic, hue = 'class')
p1=set_title("plot for counting")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 titanic = sns.load_dataset("titanic")
#       5 p1=sns.countplot(x='sex',data=titanic, hue = 'class')
# ----> 6 p1=set_title("plot for counting")
#       7 plt.show()
#
# NameError: name 'set_title' is not defined

# %%
# scatter plot
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=False)
titanic = sns.load_dataset("titanic")
g=sns.FacetGrid(titanic, row= "sex" ,hue= "alone")
g=(g.map(plt.scatter, "age","fare").add_legend())
plt.show()
